# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in ./anaconda3/lib/python3.10/site-packages (0.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in ./anaconda3/lib/python3.10/site-packages (from librosa) (1.2.1)
# Requirement already satisfied: scipy>=1.2.0 in ./anaconda3/lib/python3.10/site-packages (from librosa) (1.10.0)
# Requirement already satisfied: numba>=0.51.0 in ./anaconda3/lib/python3.10/site-packages (from librosa) (0.56.4)
# Requirement already satisfied: lazy-loader>=0.1 in ./anaconda3/lib/python3.10/site-packages (from librosa) (0.3)
# Requirement already satisfied: typing-extensions>=4.1.1 in ./anaconda3/lib/python3.10/site-packages (from librosa) (4.4.0)
# Requirement already satisfied: msgpack>=1.0 in ./anaconda3/lib/python3.10/site-packages (from librosa) (1.0.3)
# Requirement already satisfied: joblib>=0.14 in ./anaconda3/lib/python3.10/site-packages (from librosa) (1.1.1)
# Requirement already satisfied: pooch>=1.0 in ./anaconda3/lib/python3.10/site-packages (from librosa) (1.4.0)
# Requirement already satisfied: soxr>=0.3.2 in ./anaconda3/lib/python3.10/site-packages (from librosa) (0.3.7)
# Requirement already satisfied: decorator>=4.3.0 in ./anaconda3/lib/python3.10/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in ./anaconda3/lib/python3.10/site-packages (from librosa) (1.23.5)
# Requirement already satisfied: audioread>=2.1.9 in ./anaconda3/lib/python3.10/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: soundfile>=0.12.1 in ./anaconda3/lib/python3.10/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in ./anaconda3/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (0.39.1)
# Requirement already satisfied: setuptools in ./anaconda3/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (65.6.3)
# Requirement already satisfied: packaging in ./anaconda3/lib/python3.10/site-packages (from pooch>=1.0->librosa) (22.0)
# Requirement already satisfied: requests in ./anaconda3/lib/python3.10/site-packages (from pooch>=1.0->librosa) (2.28.1)
# Requirement already satisfied: appdirs in ./anaconda3/lib/python3.10/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./anaconda3/lib/python3.10/site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in ./anaconda3/lib/python3.10/site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in ./anaconda3/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in ./anaconda3/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./anaconda3/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa) (1.26.14)

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in ./anaconda3/lib/python3.10/site-packages (22.3.1)
# Collecting pip
#   Downloading pip-24.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 407.3 kB/s eta 0:00:0000:0100:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3.1
#     Uninstalling pip-22.3.1:
#       Successfully uninstalled pip-22.3.1
# Successfully installed pip-24.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# A1. Load the recorded speech file into your python workspace. Once loaded, plot the graph for the speech signal
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

y, sr = librosa.load('/Users/hariprasad/Desktop/kasavanahalli.m4a')
plt.figure(figsize=(10, 5))
librosa.display.waveshow(y)
plt.title('Speech Signal Waveform')
plt.show()
# Out:
# /var/folders/gs/1g1w50gn19s6d600bf50y3gw0000gn/T/ipykernel_14719/3775442135.py:6: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load('/Users/hariprasad/Desktop/kasavanahalli.m4a')
# /Users/hariprasad/anaconda3/lib/python3.10/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)

# %%
y.shape
# Out:
# (52127,)

# %%
# A2. Observe the length & magnitude range of the signal from the plot. Observing the plot, relate to the spoken words and silence between the words.
print("Length of the signal:",len(y),"samples")
print("Sampling rate:",sr, "Hz")
print("Magnitude range:",np.min(y),"to", np.max(y))
# Out:
# Length of the signal: 52127 samples
# Sampling rate: 22050 Hz
# Magnitude range: -0.36450025 to 0.36635226

# %%
# A3. Take a small segment of the signal and play it.
import IPython.display as ipd

start = int(0.5 * sr)
end = int(2 * sr)
segment = y[start:end]
librosa.display.waveshow(segment)
ipd.Audio(segment, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# A4. Play around with your recorded speech signal for various segments. Understand the nature of the signal. Also observe with abruptly segmented speech, how the perception of that speech is affected.
segment_1_start = int(0 * sr)
segment_1_end = int(1 * sr)
segment_2_start = int(1.5 * sr)
segment_2_end = int(2 * sr)
segment_1 = y[segment_1_start:segment_1_end]
segment_2 = y[segment_2_start:segment_2_end]
print("Playing Segment 1:")

plt.figure(figsize=(10, 5))
librosa.display.waveshow(segment_1)
plt.title('Segment-2')
plt.show()
ipd.Audio(segment_1, rate=sr)
# Out:
# Playing Segment 1:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Playing Segment 2:")

plt.figure(figsize=(10, 5))
librosa.display.waveshow(segment_2)
plt.title('Segment-1')
plt.show()
ipd.Audio(segment_2, rate=sr)
# Out:
# Playing Segment 2:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
